# %%
import pandas as pd

# %%
nytimes_covid_data = pd.read_csv('Resources/us-counties-recent.csv')

# %%
nytimes_covid_data
# Out:
#              date      county    state     fips  cases  deaths
# 0      2021-07-06     Autauga  Alabama   1001.0   7262   113.0
# 1      2021-07-06     Baldwin  Alabama   1003.0  22043   315.0
# 2      2021-07-06     Barbour  Alabama   1005.0   2347    60.0
# 3      2021-07-06        Bibb  Alabama   1007.0   2693    64.0
# 4      2021-07-06      Blount  Alabama   1009.0   6988   139.0
# ...           ...         ...      ...      ...    ...     ...
# 97387  2021-08-04  Sweetwater  Wyoming  56037.0   5042    45.0
# 97388  2021-08-04       Teton  Wyoming  56039.0   3938    11.0
# 97389  2021-08-04       Uinta  Wyoming  56041.0   2464    14.0
# 97390  2021-08-04    Washakie  Wyoming  56043.0    948    26.0
# 97391  2021-08-04      Weston  Wyoming  56045.0    689     6.0
#
# [97392 rows x 6 columns]
